# %% [markdown]
# # Main Heading
# ## sub heading
# ### small heading
#
# this is a regular text
#
# ___
#
#
# - task list 1
# - task list 2

# %%
print("hello again")
print("hello again")
# Out:
# hello again
# hello again

# %%
print("hello again and from chaicode in another cell")
# Out:
# hello again and from chaicode in another cell

# %% [markdown]
# # this is another markdown cell
#
# ____
#
# - list
# - another list

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Step 2: Create some sample data
x = [1, 2, 3, 4, 5]       # x-axis values
y = [2, 4, 6, 8, 10]      # y-axis values

# Step 3: Plot the graph
plt.plot(x, y)

# Step 4: Add labels and title
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Simple Line Graph")

# Step 5: Show the graph
plt.show()
